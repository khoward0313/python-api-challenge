# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# get citipy
# pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from scipy import stats

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# weather_api_key

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 647

# %%
cities
# Out:
# ['christchurch',
#  'sistranda',
#  'bethel',
#  'nhulunbuy',
#  'batemans bay',
#  'hopelchen',
#  'hilo',
#  'hobart',
#  'iralaya',
#  'taolanaro',
#  'hofn',
#  'busselton',
#  'alibag',
#  'rikitea',
#  'mataura',
#  'qaanaaq',
#  'diego de almagro',
#  'quelimane',
#  'ushuaia',
#  'yellowknife',
#  'ustynivka',
#  'nadadores',
#  'vila franca do campo',
#  'bolungarvik',
#  'mar del plata',
#  'lolua',
#  'pangnirtung',
#  'cravo norte',
#  'meyungs',
#  'iqaluit',
#  'ayan',
#  'kapaa',
#  'khorixas',
#  'faya',
#  'esso',
#  'kruisfontein',
#  'lebu',
#  'brokopondo',
#  'zhigansk',
#  'barrow',
#  'jacmel',
#  'jamestown',
#  'alice town',
#  'katsuura',
#  'alihe',
#  'bengkulu',
#  'olinda',
#  'albany',
#  'vaini',
#  'chokurdakh',
#  'bluff',
#  'demak',
#  'buala',
#  'havoysund',
#  'tasiilaq',
#  'ponta do sol',
#  'pevek',
#  'the valley',
#  'luderitz',
#  'cherskiy',
#  'punta arenas',
#  'ahipara',
#  'kodiak',
#  'nikolskoye',
#  'lorengau',
#  'coahuayana',
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

#         # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

#         # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

#     # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | christchurch
# Processing Record 2 of Set 1 | sistranda
# Processing Record 3 of Set 1 | bethel
# Processing Record 4 of Set 1 | nhulunbuy
# Processing Record 5 of Set 1 | batemans bay
# Processing Record 6 of Set 1 | hopelchen
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | iralaya
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | hofn
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | alibag
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | qaanaaq
# Processing Record 17 of Set 1 | diego de almagro
# Processing Record 18 of Set 1 | quelimane
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | ustynivka
# ...

# %%
city_data
# Out:
# [{'City': 'christchurch',
#   'Lat': -43.5333,
#   'Lng': 172.6333,
#   'Max Temp': 18.11,
#   'Humidity': 55,
#   'Cloudiness': 40,
#   'Wind Speed': 7.2,
#   'Country': 'NZ',
#   'Date': 1675915868},
#  {'City': 'sistranda',
#   'Lat': 63.7256,
#   'Lng': 8.834,
#   'Max Temp': 1.98,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 13.08,
#   'Country': 'NO',
#   'Date': 1675916007},
#  {'City': 'bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 4.97,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 0.45,
#   'Country': 'US',
#   'Date': 1675916007},
#  {'City': 'nhulunbuy',
#   'Lat': -12.2333,
#   'Lng': 136.7667,
#   'Max Temp': 32.34,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 1.54,
#   'Country': 'AU',
#   'Date': 1675916007},
#  {'City': 'batemans bay',
#   'Lat': -35.7167,
#   'Lng': 150.1833,
#   'Max Temp': 20.05,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 3.07,
#   'Country': 'AU',
# ...

# %%
city_weather
# Out:
# {'coord': {'lon': -114.0611, 'lat': 27.9769},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 16.01,
#   'feels_like': 15.08,
#   'temp_min': 16.01,
#   'temp_max': 16.01,
#   'pressure': 1019,
#   'humidity': 54,
#   'sea_level': 1019,
#   'grnd_level': 1019},
#  'visibility': 10000,
#  'wind': {'speed': 0.58, 'deg': 171, 'gust': 3.23},
#  'clouds': {'all': 16},
#  'dt': 1675916244,
#  'sys': {'country': 'MX', 'sunrise': 1675865954, 'sunset': 1675905702},
#  'timezone': -25200,
#  'id': 4021858,
#  'name': 'Guerrero Negro',
#  'cod': 200}

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

#Show Record Count
city_data_df.count()
# Out:
# City          591
# Lat           591
# Lng           591
# Max Temp      591
# Humidity      591
# Cloudiness    591
# Wind Speed    591
# Country       591
# Date          591
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  christchurch -43.5333  172.6333     18.11        55          40
# 1     sistranda  63.7256    8.8340      1.98        90         100
# 2        bethel  41.3712  -73.4140      4.97        64           0
# 3     nhulunbuy -12.2333  136.7667     32.34        70          40
# 4  batemans bay -35.7167  150.1833     20.05        90         100
#
#    Wind Speed Country        Date
# 0        7.20      NZ  1675915868
# 1       13.08      NO  1675916007
# 2        0.45      US  1675916007
# 3        1.54      AU  1675916007
# 4        3.07      AU  1675916008

# %%
# Export the City_Data into a csv
city_data_df.to_csv("city_data_df.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("city_data_df.csv", index_col="City_ID")

latitude = city_data_df["Lat"]

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        christchurch -43.5333  172.6333     18.11        55          40
# 1           sistranda  63.7256    8.8340      1.98        90         100
# 2              bethel  41.3712  -73.4140      4.97        64           0
# 3           nhulunbuy -12.2333  136.7667     32.34        70          40
# 4        batemans bay -35.7167  150.1833     20.05        90         100
#
#          Wind Speed Country        Date
# City_ID
# 0              7.20      NZ  1675915868
# 1             13.08      NO  1675916007
# 2              0.45      US  1675916007
# 3              1.54      AU  1675916007
# 4              3.07      AU  1675916008

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x = city_data_df["Lat"]
y = city_data_df["Max Temp"]
fig, ax = plt.subplots()
ax.scatter(x, y)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Max Latitude vs. Temperature (2022-10-18)")
ax.grid(linestyle='--', color='gray')

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x = city_data_df["Lat"]
y = city_data_df["Humidity"]
fig, ax = plt.subplots()
ax.scatter(x, y)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (2022-10-18)")
ax.grid(linestyle='--', color='gray')

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x = city_data_df["Lat"]
y = city_data_df["Cloudiness"]
fig, ax = plt.subplots()
ax.scatter(x, y)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (2022-10-18)")
ax.grid(linestyle='--', color='gray')

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x = city_data_df["Lat"]
y = city_data_df["Wind Speed"]
fig, ax = plt.subplots()
ax.scatter(x, y)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs. Wind Speed (2022-10-18)")
ax.grid(linestyle='--', color='gray')

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df =  city_data_df[ city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        sistranda  63.7256    8.8340      1.98        90         100
# 2           bethel  41.3712  -73.4140      4.97        64           0
# 5        hopelchen  19.7667  -89.8500     24.10        71           4
# 6             hilo  19.7297 -155.0900     22.85        83          75
# 8          iralaya  15.0000  -83.2333     24.50        85          15
#
#          Wind Speed Country        Date
# City_ID
# 1             13.08      NO  1675916007
# 2              0.45      US  1675916007
# 5              2.93      MX  1675916009
# 6              4.12      US  1675916009
# 8              6.22      HN  1675916010

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[ city_data_df['Lat'] <= 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        christchurch -43.5333  172.6333     18.11        55          40
# 3           nhulunbuy -12.2333  136.7667     32.34        70          40
# 4        batemans bay -35.7167  150.1833     20.05        90         100
# 7              hobart -42.8794  147.3294     21.82        56          75
# 10          busselton -33.6500  115.3333     27.94        35           0
#
#          Wind Speed Country        Date
# City_ID
# 0              7.20      NZ  1675915868
# 3              1.54      AU  1675916007
# 4              3.07      AU  1675916008
# 7              5.66      AU  1675915947
# 10             1.30      AU  1675916011

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x = northern_hemi_df["Lat"]
y = northern_hemi_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress (x,y)
regress = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x,y)

plt.plot(x, regress, "r-")
plt.annotate(line_eq,(0,-20),color="red")

plt.xlabel("Latitude")
plt.ylabel("Max Temp")

print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.7606967973710126

# %%
# Linear regression on Southern Hemisphere
x = southern_hemi_df["Lat"]
y = southern_hemi_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress (x,y)
regress = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x,y)

plt.plot(x, regress, "r-")
plt.annotate(line_eq,(0,-20),color="red")

plt.xlabel("Latitude")
plt.ylabel("Max Temp")

print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.13236024161225218

# %% [markdown]
# **Discussion about the linear relationship:** Based on the above plots cities closer to the equator tend to be hotter than those located in the direction of either poles.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df["Lat"]
y = northern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress (x,y)
regress = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x,y)

plt.plot(x, regress, "r-")
plt.annotate(line_eq,(0,-20),color="red")

plt.xlabel("Latitude")
plt.ylabel("Humidity")

print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.17299614720551335

# %%
# Southern Hemisphere
x = southern_hemi_df["Lat"]
y = southern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress (x,y)
regress = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x,y)

plt.plot(x, regress, "r-")
plt.annotate(line_eq,(0,-20),color="red")

plt.xlabel("Latitude")
plt.ylabel("Humidity")

print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.11319577139034279

# %% [markdown]
# **Discussion about the linear relationship:** Based on the above plots cities closer to the equator in Southern Hemisphere tend to be more humid, while the closer cities are to the equator in the Northern Hemisphere, the less humid they are.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df["Lat"]
y = northern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress (x,y)
regress = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x,y)

plt.plot(x, regress, "r-")
plt.annotate(line_eq,(0,-20),color="red")

plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.07679663843371187

# %%
# Southern Hemisphere
x = southern_hemi_df["Lat"]
y = southern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress (x,y)
regress = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x,y)

plt.plot(x, regress, "r-")
plt.annotate(line_eq,(0,-20),color="red")

plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.13638730537968208

# %% [markdown]
# **Discussion about the linear relationship:** Based on the above plots cities closer to the equator in the Southern hemisphere tend to be cloudier, while the closer a city is to the equator in the Northern Hemipshere, it will likely be less cloudy.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df["Lat"]
y = northern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress (x,y)
regress = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x,y)

plt.plot(x, regress, "r-")
plt.annotate(line_eq,(0,-20),color="red")

plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.021070330904317473

# %%
# Southern Hemisphere
x = southern_hemi_df["Lat"]
y = southern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress (x,y)
regress = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x,y)

plt.plot(x, regress, "r-")
plt.annotate(line_eq,(0,-20),color="red")

plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.10552691393832934

# %% [markdown]
# **Discussion about the linear relationship:** Based on the above plots it is clear that cities closer to the equator experience lower wind speeds.
